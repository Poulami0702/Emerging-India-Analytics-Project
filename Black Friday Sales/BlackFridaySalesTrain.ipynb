# %%
import pandas as pd
import numpy as np

df=pd.read_csv('C:\\Users\\nEW u\\Desktop\\DataSEts\\Black Friday Sales Prediction\\train.csv')

df.head(3)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df.drop(['User_ID','Product_ID'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# Gender                        0.000000
# Age                           0.000000
# Occupation                    0.000000
# City_Category                 0.000000
# Stay_In_Current_City_Years    0.000000
# Marital_Status                0.000000
# Product_Category_1            0.000000
# Product_Category_2            0.315666
# Product_Category_3            0.696727
# Purchase                      0.000000
# dtype: float64

# %%
df.dtypes
# Out:
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
print('The Unique element present in Gender')
print(df['Gender'].unique())
sns.countplot(df['Gender'])
plt.show()
import collections
c=collections.Counter(df['Gender'])
print('The count of Each unique element')
print(c)
# Out:
# The Unique element present in Gender
# ['F' 'M']
# The count of Each unique element
# Counter({'M': 414259, 'F': 135809})

# %%
print('The Unique element present in Age')
print(df['Age'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Age'])
plt.show()
print('The count of Each unique element')
print(df['Age'].value_counts())
# Out:
# The Unique element present in Age
# ['0-17' '55+' '26-35' '46-50' '51-55' '36-45' '18-25']
# The count of Each unique element
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
df['Age']=df['Age'].replace('55+','55')
print(df['Age'].unique())
# Out:
# ['0-17' '55' '26-35' '46-50' '51-55' '36-45' '18-25']

# %%
print('The Unique element present in Occupation')
print(df['Occupation'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Occupation'])
plt.show()
print('The count of Each unique element')
print(df['Occupation'].value_counts())
# Out:
# The Unique element present in Occupation
# [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
# The count of Each unique element
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
print('The Unique element present in City_Category')
print(df['City_Category'].unique())
#plt.figure(figsize=(10,5))
sns.countplot(df['City_Category'])
plt.show()
print('The count of Each unique element')
print(df['City_Category'].value_counts())
# Out:
# The Unique element present in City_Category
# ['A' 'C' 'B']
# The count of Each unique element
# B    231173
# C    171175
# A    147720
# Name: City_Category, dtype: int64

# %%
print('The Unique element present in Stay_In_Current_City_Years')
print(df['Stay_In_Current_City_Years'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Stay_In_Current_City_Years'])
plt.show()
print('The count of Each unique element')
print(df['Stay_In_Current_City_Years'].value_counts())
# Out:
# The Unique element present in Stay_In_Current_City_Years
# ['2' '4+' '3' '1' '0']
# The count of Each unique element
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].replace('4+','4')

print('The Unique element present in Stay_In_Current_City_Years')
print(df['Stay_In_Current_City_Years'].unique())
# Out:
# The Unique element present in Stay_In_Current_City_Years
# ['2' '4' '3' '1' '0']

# %%
print('The Unique element present in Marital_Status')
print(df['Marital_Status'].unique())
#plt.figure(figsize=(10,5))
sns.countplot(df['Marital_Status'])
plt.show()
print('The count of Each unique element')
print(df['Marital_Status'].value_counts())
# Out:
# The Unique element present in Marital_Status
# [0 1]
# The count of Each unique element
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %%
print('The Unique element present in Product_Category_1')
print(df['Product_Category_1'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Product_Category_1'])
plt.show()
print('The count of Each unique element')
print(df['Product_Category_1'].value_counts())
# Out:
# The Unique element present in Product_Category_1
# [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9 20 19]
# The count of Each unique element
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# 6      20466
# 3      20213
# 4      11753
# 16      9828
# 15      6290
# 13      5549
# 10      5125
# 12      3947
# 7       3721
# 18      3125
# 20      2550
# 19      1603
# 14      1523
# 17       578
# 9        410
# Name: Product_Category_1, dtype: int64

# %%
print('The Unique element present in Product_Category_2')
print(df['Product_Category_2'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Product_Category_2'])
plt.show()
print('The count of Each unique element')
print(df['Product_Category_2'].value_counts())
# Out:
# The Unique element present in Product_Category_2
# [nan  6. 14.  2.  8. 15. 16. 11.  5.  3.  4. 12.  9. 10. 17. 13.  7. 18.]
# The count of Each unique element
# 8.0     64088
# 14.0    55108
# 2.0     49217
# 16.0    43255
# 15.0    37855
# 5.0     26235
# 4.0     25677
# 6.0     16466
# 11.0    14134
# 17.0    13320
# 13.0    10531
# 9.0      5693
# 12.0     5528
# 10.0     3043
# 3.0      2884
# 18.0     2770
# 7.0       626
# Name: Product_Category_2, dtype: int64

# %%
print('The Unique element present in Product_Category_1')
print(df['Product_Category_3'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Product_Category_3'])
plt.show()
print('The count of Each unique element')
print(df['Product_Category_3'].value_counts())
# Out:
# The Unique element present in Product_Category_1
# [nan 14. 17.  5.  4. 16. 15.  8.  9. 13.  6. 12.  3. 18. 11. 10.]
# The count of Each unique element
# 16.0    32636
# 15.0    28013
# 14.0    18428
# 17.0    16702
# 5.0     16658
# 8.0     12562
# 9.0     11579
# 12.0     9246
# 13.0     5459
# 6.0      4890
# 18.0     4629
# 4.0      1875
# 11.0     1805
# 10.0     1726
# 3.0       613
# Name: Product_Category_3, dtype: int64

# %%
df['Product_Category_3'].isnull().mean()
# Out:
# 0.6967265865311197

# %%
df.drop(['Product_Category_3'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Purchase'],
#       dtype='object')

# %%
df.isnull().mean()
# Out:
# Gender                        0.000000
# Age                           0.000000
# Occupation                    0.000000
# City_Category                 0.000000
# Stay_In_Current_City_Years    0.000000
# Marital_Status                0.000000
# Product_Category_1            0.000000
# Product_Category_2            0.315666
# Purchase                      0.000000
# dtype: float64

# %%
df1=df.copy()

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().mean()
# Out:
# Gender                        0.0
# Age                           0.0
# Occupation                    0.0
# City_Category                 0.0
# Stay_In_Current_City_Years    0.0
# Marital_Status                0.0
# Product_Category_1            0.0
# Product_Category_2            0.0
# Purchase                      0.0
# dtype: float64

# %%
from scipy.stats import norm
plt.figure(figsize=(10,5))
sns.distplot(df1['Purchase'], color='maroon', fit=norm, kde=False)
# Out:
# C:\Users\nEW u\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df1.dtypes
# Out:
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Purchase                        int64
# dtype: object

# %%
df1['Occupation']=df1['Occupation'].astype('object')

# %%
df1['Occupation'].dtypes, df1['Age'].dtypes
# Out:
# (dtype('O'), dtype('O'))

# %%
df1.dtypes
# Out:
# Gender                         object
# Age                            object
# Occupation                     object
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Purchase                        int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df1['Gender']=l.fit_transform(df1['Gender'])
df1['Age']=l.fit_transform(df1['Age'])
df1['Occupation']=l.fit_transform(df1['Occupation'])
df1['City_Category']=l.fit_transform(df1['City_Category'])
df1['Stay_In_Current_City_Years']=l.fit_transform(df1['Stay_In_Current_City_Years'])

# %%
df1.head()
# Out:
#    Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 1       0    0          10              0                           2
# 3       0    0          10              0                           2
# 5       1    2          15              0                           3
# 6       1    4           7              1                           2
# 7       1    4           7              1                           2
#
#    Marital_Status  Product_Category_1  Product_Category_2  Purchase
# 1               0                   1                 6.0     15200
# 3               0                  12                14.0      1057
# 5               0                   1                 2.0     15227
# 6               1                   1                 8.0     19215
# 7               1                   1                15.0     15854

# %%
df1['Occupation'].unique()
# Out:
# array([10, 15,  7, 20,  9,  1, 12, 17,  0,  3, 16,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df1['Product_Category_2']=df1['Product_Category_2'].astype('int64')

# %%
df1.head(1)
# Out:
#    Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 1       0    0          10              0                           2
#
#    Marital_Status  Product_Category_1  Product_Category_2  Purchase
# 1               0                   1                   6     15200

# %%
X=df1.drop(['Purchase'], axis=True)
y=df1['Purchase']

# %%
X.head(1)
# Out:
#    Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 1       0    0          10              0                           2
#
#    Marital_Status  Product_Category_1  Product_Category_2
# 1               0                   1                   6

# %%
from sklearn.preprocessing import MinMaxScaler
df_num_scl=MinMaxScaler()
x=df_num_scl.fit_transform(X)

# %%
x[:1]
# Out:
# array([[0.  , 0.  , 0.5 , 0.  , 0.5 , 0.  , 0.  , 0.25]])

# %%
x=pd.DataFrame(data=x, columns=X.columns)

# %%
x.head(1)
# Out:
#    Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0     0.0  0.0         0.5            0.0                         0.5
#
#    Marital_Status  Product_Category_1  Product_Category_2
# 0             0.0                 0.0                0.25

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((301144, 8), (75286, 8), (301144,), (75286,))

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model=lr.fit(X_train, y_train)

# %%
model.score(X_test,y_test)
# Out:
# 0.18104089242935406

# %%
from sklearn.ensemble import RandomForestRegressor
ran_for = RandomForestRegressor(n_estimators=10, criterion='mae', max_depth=10,random_state=42)
ran_for.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
ran_for.score(X_test,y_test)
# Out:
# 0.6018166802558425

# %%
from sklearn.model_selection import cross_val_score
lR=cross_val_score(RandomForestRegressor(),X_train, y_train, cv=5)

# %%
print(lR)
print('The mean Average score')
print(np.mean(lR))
# Out:
# [0.58760382 0.59538176 0.59146036 0.59699361 0.59192612]
# The mean Average score
# 0.5926731337646629
